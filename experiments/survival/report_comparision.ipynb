# %%
import os 
from itables import show
import pandas as pd
import plotly.express as px
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib inline

import Orange #version 3.33
from Orange.evaluation import compute_CD, graph_ranks
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def plot_box(df, for_field, title, y_axis):
    fig = px.bar(df, x='dataset', color="model",
                y=for_field,
                barmode='group',
                #text_auto=True,
                #height=560,
                #width=3000,
                title=title,
                )
    fig.update_traces(textposition='outside')
    fig.update_layout(
                title={
                'x':0.5,
                'xanchor': 'center'
            })
    fig.update_layout(yaxis_title=y_axis)
    fig.show()

# %%
results_df = pd.read_csv(f"./results/comparision/exceptions_summary_ALL.csv")

# %%
show(results_df)
# Out:
# <table id="itables_dcf2e445_4011_44f1_9099_f61aa967685f" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>dataset</th>
#       <th>model</th>
#       <th>thread_time</th>
#       <th>process_time</th>
#       <th>raw_time</th>
#       <th>liczba_regul</th>
#       <th>liczba_wyjatkow</th>
#       <th>srednia_dlugosc_reguly</th>
#       <th>suma_warunkow</th>
#       <th>avg_coverage</th>
#       <th>ibs_train</th>
#       <th>ibs_test</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.2.2 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_dcf2e445_4011_44f1_9099_f61aa967685f:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["01_lung.arff", "algorithm_rulekit", 0.951968, 8.454063, 1.90069, 4, 0, 1.25, 5, 0.51, 0.147228, 0.154579], ["01_lung.arff", "algorithm_log_rank", 2.51734, 2.53107, 2.517475, 2, 0, 1.0, 2, 0.7, 0.146608, 0.157916], ["01_lung.arff", "algorithm_log_rank_with_exceptions", 6.096898, 6.100251, 6.097332, 2, 1, 1.0, 2, 0.7, 0.143635, 0.154953], ["01_lung.arff", "survival_tree", 0.012715, 0.019731, 0.012723, 28, 0, 4.857143, 136, 0.0, 0.122591, 0.145329], ["02_csb-ch15-lung.arff", "algorithm_rulekit", 0.232691, 9.948367, 0.47521, 5, 0, 1.4, 7, 0.42, 0.138143, 0.145168], ["02_csb-ch15-lung.arff", "algorithm_log_rank", 2.630613, 2.632235, 2.630894, 2, 0, 1.0, 2, 0.69, 0.150085, 0.150281], ["02_csb-ch15-lung.arff", "algorithm_log_rank_with_exceptions", 4.238618, 4.240019, 4.240197, 2, 2, 1.0, 2, 0.69, 0.145452, 0.147189], ["02_csb-ch15-lung.arff", "survival_tree", 0.012025, 0.036411, 0.012024, 32, 0, 5.0, 160, 0.0, 0.122392, 0.148188], ["03_csb-ch07-halibut.arff", "algorithm_rulekit", 0.093851, 4.047119, 0.444639, 7, 0, 3.714286, 26, 0.48, 0.049911, 0.046163], ["03_csb-ch07-halibut.arff", "algorithm_log_rank", 7.072693, 7.078037, 7.072813, 5, 0, 3.8, 19, 0.49, 0.050343, 0.046845], ["03_csb-ch07-halibut.arff", "algorithm_log_rank_with_exceptions", 22.097201, 22.104242, 22.098353, 4, 1, 3.75, 15, 0.46, 0.078363, 0.06531], ["03_csb-ch07-halibut.arff", "survival_tree", 0.00876, 0.026536, 0.00876, 22, 0, 4.636364, 102, 0.0, 0.038119, 0.0553], ["04_BHS.arff", "algorithm_rulekit", 0.068102, 1.727385, 0.353523, 4, 0, 1.5, 6, 0.46, 0.097586, 0.117613], ["04_BHS.arff", "algorithm_log_rank", 4.480094, 4.482089, 4.48011, 3, 0, 1.666667, 5, 0.53, 0.086071, 0.137047], ["04_BHS.arff", "algorithm_log_rank_with_exceptions", 17.943675, 17.951593, 17.943966, 3, 0, 1.666667, 5, 0.53, 0.086071, 0.137047], ["04_BHS.arff", "survival_tree", 0.007274, 0.007309, 0.007273, 8, 0, 3.25, 26, 0.0, 0.035423, 0.204551], ["05_Rossi.arff", "algorithm_rulekit", 0.462087, 3.110958, 0.708678, 12, 0, 2.166667, 26, 0.4, 0.103663, 0.128396], ["05_Rossi.arff", "algorithm_log_rank", 9.065645, 9.069048, 9.065648, 7, 0, 3.571429, 25, 0.21, 0.109803, 0.118404], ["05_Rossi.arff", "algorithm_log_rank_with_exceptions", 42.300116, 42.31329, 42.312613, 7, 0, 3.571429, 25, 0.21, 0.109803, 0.118404], ["05_Rossi.arff", "survival_tree", 0.047658, 0.047748, 0.047641, 20, 0, 4.65, 93, 0.0, 0.032241, 0.045521], ["06_unemployed.arff", "algorithm_rulekit", 0.150637, 1.85572, 0.361694, 15, 0, 2.533333, 38, 0.22, 0.165411, 0.154621], ["06_unemployed.arff", "algorithm_log_rank", 13.212862, 13.217323, 13.214944, 14, 0, 2.5, 35, 0.22, 0.165652, 0.152203], ["06_unemployed.arff", "algorithm_log_rank_with_exceptions", 41.968941, 41.983612, 41.983061, 8, 1, 2.25, 18, 0.22, 0.182155, 0.156734], ["06_unemployed.arff", "survival_tree", 0.012643, 0.027528, 0.012642, 21, 0, 4.666667, 98, 0.0, 0.150979, 0.226807], ["07_Melanoma.arff", "algorithm_rulekit", 0.114824, 0.410549, 0.180597, 8, 0, 3.0, 24, 0.43, 0.161329, 0.132226], ["07_Melanoma.arff", "algorithm_log_rank", 11.757404, 11.764707, 11.75963, 7, 0, 3.0, 21, 0.43, 0.157657, 0.132203], ["07_Melanoma.arff", "algorithm_log_rank_with_exceptions", 52.011198, 52.02897, 52.019308, 7, 0, 3.0, 21, 0.43, 0.157657, 0.132203], ["07_Melanoma.arff", "survival_tree", 0.011788, 0.011868, 0.011788, 20, 0, 4.5, 90, 0.0, 0.077802, 0.167793], ["08_mgus.arff", "algorithm_rulekit", 0.121485, 0.858478, 0.296969, 8, 0, 2.375, 19, 0.38, 0.127572, 0.188037], ["08_mgus.arff", "algorithm_log_rank", 21.026686, 21.037007, 21.031307, 7, 0, 2.428571, 17, 0.35, 0.127191, 0.18773], ["08_mgus.arff", "algorithm_log_rank_with_exceptions", 35.965923, 35.976983, 35.970909, 3, 1, 2.333333, 7, 0.43, 0.13889, 0.202883], ["08_mgus.arff", "survival_tree", 0.013227, 0.040049, 0.013227, 10, 0, 3.8, 38, 0.0, 0.113008, 0.186077], ["09_std.a

# %% [markdown]
# ### Wykresy

# %% [markdown]
# #### IBS on test

# %%
plot_box(results_df, "ibs_test", title='IBS on test', y_axis="IBS")
# Out:
# <div>                            <div id="0ab1ecbf-fb74-4d77-9e01-b6e03a074d5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ab1ecbf-fb74-4d77-9e01-b6e03a074d5d")) {                    Plotly.newPlot(                        "0ab1ecbf-fb74-4d77-9e01-b6e03a074d5d",                        [{"alignmentgroup":"True","hovertemplate":"model=algorithm_rulekit\u003cbr\u003edataset=%{x}\u003cbr\u003eibs_test=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"algorithm_rulekit","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"algorithm_rulekit","offsetgroup":"algorithm_rulekit","orientation":"v","showlegend":true,"textposition":"outside","x":["01_lung.arff","02_csb-ch15-lung.arff","03_csb-ch07-halibut.arff","04_BHS.arff","05_Rossi.arff","06_unemployed.arff","07_Melanoma.arff","08_mgus.arff","09_std.arff","10_hd.arff","11_follic.arff","12_cancer.arff","13_uis.arff","14_whas1.arff","15_csb-ch12-nursing.arff","16_bmt-ch.arff","17_przeszczepy.arff","18_zinc.arff","19_GBSG2.arff","20_whas500.arff","21_actg320.arff","22_wcgs.arff","23_lac_selected.arff","24_pbc.arff","25_TRACE.arff"],"xaxis":"x","y":[0.1545785037996505,0.1451676031001982,0.0461633732134982,0.1176130511593804,0.1283959239612347,0.1546212203209176,0.1322257631575507,0.1880372732516285,0.1909446293119639,0.2020235228475639,0.1864868764723272,0.1285943960568381,0.1513575525528494,0.2844619299924524,0.1589491129815195,0.2478061469361031,0.2222255917597051,0.1054456369395734,0.1826399927823991,0.2191611430123677,0.0695018878833508,0.0391305628467017,0.2188840076895178,0.1866830256392151,0.2096257203807097],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"model=algorithm_log_rank\u003cbr\u003edataset=%{x}\u003cbr\u003eibs_test=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"algorithm_log_rank","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"algorithm_log_rank","offsetgroup":"algorithm_log_rank","orientation":"v","showlegend":true,"textposition":"outside","x":["01_lung.arff","02_csb-ch15-lung.arff","03_csb-ch07-halibut.arff","04_BHS.arff","05_Rossi.arff","06_unemployed.arff","07_Melanoma.arff","08_mgus.arff","09_std.arff","10_hd.arff","11_follic.arff","12_cancer.arff","13_uis.arff","14_whas1.arff","15_csb-ch12-nursing.arff","16_bmt-ch.arff","17_przeszczepy.arff","18_zinc.arff","19_GBSG2.arff","20_whas500.arff","21_actg320.arff","22_wcgs.arff","23_lac_selected.arff","24_pbc.arff","25_TRACE.arff"],"xaxis":"x","y":[0.1579157160433081,0.1502807213268558,0.0468448367513819,0.1370471559272461,0.1184038099610631,0.1522033380239745,0.1322026832755097,0.187730448917614,0.1909446293119639,0.2040266798370623,0.1900367850862004,0.1322885127978045,0.1408997477114911,0.2844619299924524,0.1592591511013199,0.2483199565701307,0.2222255917597051,0.1269319400186689,0.1828611343267761,0.2315415378615679,0.0701497780041002,0.0397492476463142,0.2188840076895178,0.1981735351744615,0.2117909408667996],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"model=algorithm_log_rank_with_exceptions\u003cbr\u003edataset=%{x}\u003cbr\u003eibs_test=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"algorithm_log_rank_with_exceptions","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"algorithm_log_rank_with_exceptions","offsetgroup":"algorithm_log_rank_with_exceptions","orientation":"v","showlegend":true,"textposition":"outside","x":["01_lung.arff","02_csb-ch15-lung.arff","03_csb-ch07-halibut.arff","04_BHS.arff","05_Rossi.arff","06_unemployed.arff","07_Melanoma.arff","08_mgus.arff","09_std.arff","10_hd.arff","11_follic.arff","12_cancer.arff","13_uis.arff","14_whas1.arff","15_csb-ch12-nursing.arff","16_bmt-ch.arff","17_przeszczepy.arff","18_zinc.arff","19_GBSG2.arff","20_whas500.ar ...

# %% [markdown]
# #### Liczba_regul

# %%
plot_box(results_df, "liczba_regul", title='Liczba regul', y_axis="Liczba regul")
# Out:
# <div>                            <div id="aca4882b-68b9-415a-8ef6-6a4c6b0563df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aca4882b-68b9-415a-8ef6-6a4c6b0563df")) {                    Plotly.newPlot(                        "aca4882b-68b9-415a-8ef6-6a4c6b0563df",                        [{"alignmentgroup":"True","hovertemplate":"model=algorithm_rulekit\u003cbr\u003edataset=%{x}\u003cbr\u003eliczba_regul=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"algorithm_rulekit","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"algorithm_rulekit","offsetgroup":"algorithm_rulekit","orientation":"v","showlegend":true,"textposition":"outside","x":["01_lung.arff","02_csb-ch15-lung.arff","03_csb-ch07-halibut.arff","04_BHS.arff","05_Rossi.arff","06_unemployed.arff","07_Melanoma.arff","08_mgus.arff","09_std.arff","10_hd.arff","11_follic.arff","12_cancer.arff","13_uis.arff","14_whas1.arff","15_csb-ch12-nursing.arff","16_bmt-ch.arff","17_przeszczepy.arff","18_zinc.arff","19_GBSG2.arff","20_whas500.arff","21_actg320.arff","22_wcgs.arff","23_lac_selected.arff","24_pbc.arff","25_TRACE.arff"],"xaxis":"x","y":[4,5,7,4,12,15,8,8,7,2,8,10,2,2,18,3,2,4,15,2,17,10,5,2,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"model=algorithm_log_rank\u003cbr\u003edataset=%{x}\u003cbr\u003eliczba_regul=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"algorithm_log_rank","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"algorithm_log_rank","offsetgroup":"algorithm_log_rank","orientation":"v","showlegend":true,"textposition":"outside","x":["01_lung.arff","02_csb-ch15-lung.arff","03_csb-ch07-halibut.arff","04_BHS.arff","05_Rossi.arff","06_unemployed.arff","07_Melanoma.arff","08_mgus.arff","09_std.arff","10_hd.arff","11_follic.arff","12_cancer.arff","13_uis.arff","14_whas1.arff","15_csb-ch12-nursing.arff","16_bmt-ch.arff","17_przeszczepy.arff","18_zinc.arff","19_GBSG2.arff","20_whas500.arff","21_actg320.arff","22_wcgs.arff","23_lac_selected.arff","24_pbc.arff","25_TRACE.arff"],"xaxis":"x","y":[2,2,5,3,7,14,7,7,7,2,7,7,2,2,17,2,2,2,14,2,16,7,4,2,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"model=algorithm_log_rank_with_exceptions\u003cbr\u003edataset=%{x}\u003cbr\u003eliczba_regul=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"algorithm_log_rank_with_exceptions","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"algorithm_log_rank_with_exceptions","offsetgroup":"algorithm_log_rank_with_exceptions","orientation":"v","showlegend":true,"textposition":"outside","x":["01_lung.arff","02_csb-ch15-lung.arff","03_csb-ch07-halibut.arff","04_BHS.arff","05_Rossi.arff","06_unemployed.arff","07_Melanoma.arff","08_mgus.arff","09_std.arff","10_hd.arff","11_follic.arff","12_cancer.arff","13_uis.arff","14_whas1.arff","15_csb-ch12-nursing.arff","16_bmt-ch.arff","17_przeszczepy.arff","18_zinc.arff","19_GBSG2.arff","20_whas500.arff","21_actg320.arff","22_wcgs.arff","23_lac_selected.arff","24_pbc.arff","25_TRACE.arff"],"xaxis":"x","y":[2,2,4,3,7,8,7,3,7,2,3,7,2,2,17,2,2,2,7,2,16,4,3,2,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"model=survival_tree\u003cbr\u003edataset=%{x}\u003cbr\u003eliczba_regul=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survival_tree","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"survival_tree","offsetgroup":"survival_tree","orientation":"v","showlegend":true,"textposition":"outside","x":["01_lung.arff","02_csb-ch15-lung.arff","03_csb-ch07-halibut.arff","04_BHS.arff","05_Rossi.arff","06_unemployed.arff","07_Melanoma.arff","08_mgus.arff","09_std.arff","10_hd.arff","11_follic.arff","12_cancer.arff","13_uis.arff","14_whas1.arff","15_csb-ch12-nursing.arff","16_bmt-c ...

# %% [markdown]
# ### Tabele

# %%
def get_table(df, wskaznik):
    df = results_df[["dataset", "model", wskaznik]]

    df = df.pivot(
        index="dataset", 
        columns= "model", 
        values=wskaznik
        )

    show(df)

# %% [markdown]
# #### IBS on test

# %%
wskaznik = "ibs_test"
get_table(results_df, wskaznik)
# Out:
# <table id="itables_45f310ba_a0bd_41c6_9fad_0e1e70d5d8f5" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>algorithm_log_rank</th>
#       <th>algorithm_log_rank_with_exceptions</th>
#       <th>algorithm_rulekit</th>
#       <th>survival_tree</th>
#     </tr>
#     <tr>
#       <th>dataset</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.2.2 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_45f310ba_a0bd_41c6_9fad_0e1e70d5d8f5:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["01_lung.arff", 0.157916, 0.154953, 0.154579, 0.145329], ["02_csb-ch15-lung.arff", 0.150281, 0.147189, 0.145168, 0.148188], ["03_csb-ch07-halibut.arff", 0.046845, 0.06531, 0.046163, 0.0553], ["04_BHS.arff", 0.137047, 0.137047, 0.117613, 0.204551], ["05_Rossi.arff", 0.118404, 0.118404, 0.128396, 0.045521], ["06_unemployed.arff", 0.152203, 0.156734, 0.154621, 0.226807], ["07_Melanoma.arff", 0.132203, 0.132203, 0.132226, 0.167793], ["08_mgus.arff", 0.18773, 0.202883, 0.188037, 0.186077], ["09_std.arff", 0.190945, 0.21534, 0.190945, 0.224037], ["10_hd.arff", 0.204027, 0.204027, 0.202024, 0.209276], ["11_follic.arff", 0.190037, 0.204965, 0.186487, 0.208534], ["12_cancer.arff", 0.132289, 0.132289, 0.128594, 0.181964], ["13_uis.arff", 0.1409, 0.1409, 0.151358, 0.155087], ["14_whas1.arff", 0.284462, 0.270381, 0.284462, 0.27574], ["15_csb-ch12-nursing.arff", 0.159259, 0.159259, 0.158949, 0.159463], ["16_bmt-ch.arff", 0.24832, 0.24832, 0.247806, 0.205058], ["17_przeszczepy.arff", 0.222226, 0.222226, 0.222226, 0.359767], ["18_zinc.arff", 0.126932, 0.126932, 0.105446, 0.127719], ["19_GBSG2.arff", 0.182861, 0.193719, 0.18264, 0.187251], ["20_whas500.arff", 0.231542, 0.23906, 0.219161, 0.228065], ["21_actg320.arff", 0.07015, 0.07015, 0.069502, 0.095464], ["22_wcgs.arff", 0.039749, 0.047753, 0.039131, 0.04167], ["23_lac_selected.arff", 0.218884, 0.223248, 0.218884, 0.30766], ["24_pbc.arff", 0.198174, 0.178385, 0.186683, 0.146497], ["25_TRACE.arff", 0.211791, 0.211791, 0.209626, 0.171039]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %% [markdown]
# #### Liczba_regul

# %%
wskaznik = "liczba_regul"
get_table(results_df, wskaznik)
# Out:
# <table id="itables_f0745f48_17fc_4048_9d2e_ea3ebafd2ac3" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th>model</th>
#       <th>algorithm_log_rank</th>
#       <th>algorithm_log_rank_with_exceptions</th>
#       <th>algorithm_rulekit</th>
#       <th>survival_tree</th>
#     </tr>
#     <tr>
#       <th>dataset</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.2.2 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_f0745f48_17fc_4048_9d2e_ea3ebafd2ac3:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["01_lung.arff", 2, 2, 4, 28], ["02_csb-ch15-lung.arff", 2, 2, 5, 32], ["03_csb-ch07-halibut.arff", 5, 4, 7, 22], ["04_BHS.arff", 3, 3, 4, 8], ["05_Rossi.arff", 7, 7, 12, 20], ["06_unemployed.arff", 14, 8, 15, 21], ["07_Melanoma.arff", 7, 7, 8, 20], ["08_mgus.arff", 7, 3, 8, 10], ["09_std.arff", 7, 7, 7, 15], ["10_hd.arff", 2, 2, 2, 26], ["11_follic.arff", 7, 3, 8, 26], ["12_cancer.arff", 7, 7, 10, 20], ["13_uis.arff", 2, 2, 2, 13], ["14_whas1.arff", 2, 2, 2, 24], ["15_csb-ch12-nursing.arff", 17, 17, 18, 30], ["16_bmt-ch.arff", 2, 2, 3, 11], ["17_przeszczepy.arff", 2, 2, 2, 11], ["18_zinc.arff", 2, 2, 4, 14], ["19_GBSG2.arff", 14, 7, 15, 15], ["20_whas500.arff", 2, 2, 2, 22], ["21_actg320.arff", 16, 16, 17, 22], ["22_wcgs.arff", 7, 4, 10, 27], ["23_lac_selected.arff", 4, 3, 5, 9], ["24_pbc.arff", 2, 2, 2, 19], ["25_TRACE.arff", 2, 2, 3, 28]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ### Ranking & CD_diagramy

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Zbiór testowy

# %%
ranking_df = results_df
ranking_df = ranking_df.pivot(index='dataset', columns='model', values='ibs_test')
ranking_df.columns.name = None

ranked_df = ranking_df.rank(axis=1, method='average', ascending=True)

# %%
average_ranks = ranked_df.mean()
average_ranks
# Out:
# algorithm_log_rank                    2.48
# algorithm_log_rank_with_exceptions    2.78
# algorithm_rulekit                     1.78
# survival_tree                         2.96
# dtype: float64

# %%
plt.figure(figsize=(10, 4))

cd = compute_CD(alpha="0.05", avranks=average_ranks, n = ranked_df.shape[0],  test = "nemenyi")

plot = graph_ranks(avranks=average_ranks, names = ranked_df.columns.values, cd = cd)

plt.savefig("./plots/ibs_test.pdf", bbox_inches="tight")  # wektorowy!
plt.savefig("./plots/ibs_test.png", dpi=600, bbox_inches="tight")  # raster high-res
plt.close()
# Out:
# C:\Users\dawid\AppData\Local\Temp\ipykernel_37548\931211003.py:3: OrangeDeprecationWarning:
#
# compute_CD is deprecated and will be removed in Orange 3.34.
#
# C:\Users\dawid\AppData\Local\Temp\ipykernel_37548\931211003.py:5: OrangeDeprecationWarning:
#
# graph_ranks is deprecated and will be removed in Orange 3.34.

# %% [markdown]
# #### Liczba reguł

# %%
ranking_df = results_df
ranking_df = ranking_df.pivot(index='dataset', columns='model', values='liczba_regul')
ranking_df.columns.name = None

ranked_df = ranking_df.rank(axis=1, method='average', ascending=True)

# %%
average_ranks = ranked_df.mean()
average_ranks
# Out:
# algorithm_log_rank                    1.78
# algorithm_log_rank_with_exceptions    1.50
# algorithm_rulekit                     2.74
# survival_tree                         3.98
# dtype: float64

# %%
plt.figure(figsize=(10, 4))

cd = compute_CD(alpha="0.05", avranks=average_ranks, n = ranked_df.shape[0],  test = "nemenyi")

plot = graph_ranks(avranks=average_ranks, names = ranked_df.columns.values, cd = cd)

plt.savefig("./plots/liczba_regul.pdf", bbox_inches="tight")  # wektorowy!
plt.savefig("./plots/liczba_regul.png", dpi=600, bbox_inches="tight")  # raster high-res
plt.close()
# Out:
# C:\Users\dawid\AppData\Local\Temp\ipykernel_37548\1132932394.py:3: OrangeDeprecationWarning:
#
# compute_CD is deprecated and will be removed in Orange 3.34.
#
# C:\Users\dawid\AppData\Local\Temp\ipykernel_37548\1132932394.py:5: OrangeDeprecationWarning:
#
# graph_ranks is deprecated and will be removed in Orange 3.34.
